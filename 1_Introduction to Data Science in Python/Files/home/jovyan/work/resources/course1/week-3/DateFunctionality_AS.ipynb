# %%
#Pandas has 4 time related classess
#1. Timestamp
#2. DatetimeIndex
#3. Period
#4. PeriodIndex

# %%
import pandas as pd

# %%
timestamp = pd.Timestamp(ts_input = '18 Jan 2023')
timestamp
# Out:
# Timestamp('2023-01-18 00:00:00')

# %%
timestamp = timestamp +  pd.Timedelta(days =2)
timestamp
# Out:
# Timestamp('2023-01-22 00:00:00')

# %%
#timestamp.isoweekday()
timestamp.second
timestamp.second
# Out:
# 0

# %%
period = pd.Period(value = 'Jan 2023')
period
# Out:
# Period('2023-01', 'M')

# %%
period = pd.Period()

# %%
index = pd.DatetimeIndex(['01 Jan 2023', '02 Jan 2023', '03 Jan 2023'])

# %%
index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(data = [[1,2], [3,4], [5,6]] , index = index, columns = ['a','b'])

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
