# %%
# Regulator expression is a patter, which is provided to a processor along with some data
# Only 3 reasons why would want to do this
# 1. TO check if a pattern exists within some source data
# 2. To all the isntances of a complex pattern 
#3 Clean your source data using a pattern genrally through string splitting
# Regexes are not trivial. They are a foundational technique for data cleaning in data science applications

# %%
# In this lecture, basic understanding of regexes
# How to define patterns for matching
# How to apply these patterns
# How to use the results of those patterns in data processing

# %%
# Import the re module
import re

# %% [markdown]
# # 1## Several main processing functions
# #1. match() - check for a match at the begining of a string and returns a boolean
# #2 Search ()  - Check for a match anywhere in the string and return a boolean
# #3 findall () will look for a pattern and pull out all occurences

# %%
text = "This is a good day."

if re.search("good", text):
    print("Wonderful!")
else: 
    print("Alas :(")
# Out:
# Wonderful!

# %%
re.search("^T", text)     #returns a match object
# Out:
# <re.Match object; span=(0, 1), match='T'>

# %%
re.match("T", text)
# Out:
# <re.Match object; span=(0, 1), match='T'>

# %%
# We can also segment a string, divide a string into tokens
text = "Amy works diligently. Amy gets good grades. Our student Amy is successful."
re.split("Amy", text) # Uses a pattern for creating a list of sub-strings
# Out:
# ['',
#  ' works diligently. ',
#  ' gets good grades. Our student ',
#  ' is successful.']

# %%
re.findall("Amy", text) #Looks for a pattern and pull out all occurences
# Out:
# ['Amy', 'Amy', 'Amy']

# %% [markdown]
# # anchors - start of string
# # Caret character - start of the string
# # $  Dollar sign character means the end.
# text = "Amy works diligently. Amy gets good grades. Our student Amy is successful."
# re.search("^Amy", text) #Returns an re match object An re match object always havs a boolean value and so can be evlauted in and if statement

# %%
#Lets create a string of single learners grades over a semester in one course across all their assignments

grades = "ACAAAABCBCBA"

# %%
# How many B's did the student get

len(re.findall("B", grades))
# Out:
# 3

# %%
# find instances of all As or Bs 
# [] is a set, we are searaching for either A or B
re.findall ("[AB]", grades)
# Out:
# ['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'A']

# %%
# [] is all called the set operator
# find out all grades that were not A

re.findall("[^A]", grades)
# Out:
# ['C', 'B', 'C', 'B', 'C', 'B']

# %%
re.findall("^[^A]", grades)
# Out:
# []

# %% [markdown]
# #### Quantifiers

# %%
re.findall("A{1,2}", grades)
# Out:
# ['A', 'AA', 'AA', 'A']

# %%
re.findall("A{2,2}", grades)
# Out:
# ['AA', 'AA']

# %%
re.findall("[AB]{1,2}", grades)
# Out:
# ['A', 'AA', 'AA', 'B', 'B', 'BA']

# %%
re.findall("[A-Z]{1,2}", grades)
# Out:
# ['AC', 'AA', 'AA', 'BC', 'BC', 'BA']

# %%
with open(r"C:\Users\singl\Applied Data Science -University of Michigan\Week_1_Files\Files\home\jovyan\work\resources\course1\week-1\datasets\ferpa.txt", mode = "r") as file:
#with open(r'C:\Users\singl\Applied Data Science -University of Michigan\Files\home\jovyan\work\resources\course1\week-1\datasets\mpg.csv') as csvfile:    
        wiki = file.read()
wiki
# Out:
# 'Overview[edit]\nFERPA gives parents access to their child\'s education records, an opportunity to seek to have the records amended, and some control over the disclosure of information from the records. With several exceptions, schools must have a student\'s consent prior to the disclosure of education records after that student is 18 years old. The law applies only to educational agencies and institutions that receive funds under a program administered by the U.S. Department of Education.\n\nOther regulations under this act, effective starting January 3, 2012, allow for greater disclosures of personal and directory student identifying information and regulate student IDs and e-mail addresses.[2] For example, schools may provide external companies with a student\'s personally identifiable information without the student\'s consent.[2]\n\nExamples of situations affected by FERPA include school employees divulging information to anyone other than the student about the student\'s grades
# ...

# %%
re.findall("[a-zA-Z]{1,100}\[edit\]", wiki)
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %%
#Headers all have the word edit and braces behind them
#\w can be used to match any letter including digits and numbers
# \w = metcharacter, indicates a special pattern of any letter or digit
# \s  matches any whitespace character
re.findall("[\w]{1,100}\[edit\]", wiki)
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %% [markdown]
# ## Three other quantifiers, we can use which shorten up the curly brace syntax
# #An asterix can be used to match 0 or more times

# %%
#Limit of searching for 1-100 characters removed by using asterix
re.findall("[\w]*\[edit\]", wiki)
# Out:
# ['Overview[edit]', 'records[edit]', 'records[edit]']

# %%
#Add whitepsace to the set of acceptable chracters in the title 
re.findall("[\w ]*\[edit\]", wiki)
# Out:
# ['Overview[edit]',
#  'Access to public records[edit]',
#  'Student medical records[edit]']

# %%
for title in re.findall("[\w ]*\[edit\]", wiki):
    print(title)
    print(re.split("[\[]", title)[0])
# Out:
# Overview[edit]
# Overview
# Access to public records[edit]
# Access to public records
# Student medical records[edit]
# Student medical records

# %% [markdown]
# ### Groups

# %%
#Till this point we have been taking about reg-ex as a single pattern which is matched

# %%
#groups are contained within paranthesis
re.findall("([\w ]*)(\[edit\])", wiki)
# Out:
# [('Overview', '[edit]'),
#  ('Access to public records', '[edit]'),
#  ('Student medical records', '[edit]')]

# %%
#labelling or naming groups. Labelling Groups is useful

# %% [markdown]
# # What is the correct regular expression to match a URL with letters, numbers, underscores and dots? A valid URL defined in this problem must meet the following requirements:
#
# The URL consists of two or more strings made of letters, numbers, and underscores.
# A dot is used in between the strings.
# No two dots are allowed to appear consecutively.
# For example, your regex should match URLs like: www.aBC.com, abc.com, ab_c.de8f.com
# But your regex should not match: abc, abc..com

# %%
text = 'www.google_.com'

pattern = '[\w]*.[\w]*.[\w]{1,3}'

re.findall(pattern, text)
# Out:
# ['www.google_.com']

# %%
# question 1
pattern = "^a|e|i|o|u[\w]*$[^a|e|i|o|u]"

test1 = 'unicorn'

re.findall(pattern, test1)
# Out:
# ['i', 'o']

# %%
#Question 2

octal_pattern = "[0][ox][1-7]*"
hexadecimal_pattern = "[0][ox][1-9a-f]*"

pattern = octal_pattern|hexadecimal_pattern
print(pattern)
test1 = '0012f'

re.findall(pattern, test1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50324/3796225028.py in <module>
#       4 hexadecimal_pattern = "[0][ox][1-9a-f]*"
#       5
# ----> 6 pattern = octal_pattern|hexadecimal_pattern
#       7 print(pattern)
#       8 test1 = '0012f'
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
#Question 3 

#Jane Doe is eating breakfast.
#Your regex should capture "Jane Doe".
#But in sentence
#Today is John Doe's birthday.

pattern = ''^[A-Z][a-z]*\\s[A-Z][a-z]*\\s"

test1 = 'L Zhang'
test 2 'Isaac Newton'

re.findall(pattern, test1)
# Out:
#   File "C:\Users\singl\AppData\Local\Temp/ipykernel_50324/4289517677.py", line 8
#     pattern = ''^[A-Z][a-z]*\\s[A-Z][a-z]*\\s"
#                                              ^
# SyntaxError: unexpected character after line continuation character

# %%
#Question 4

pattern1 = "\$[1-9][0-9]*^."

pattern2 = "\$[1-9][0-9]*.[0-9][1-9]"

pattern = "(\$[1-9][0-9]*^.)(\$[1-9][0-9]*.[0-9][1-9])"

test1 = '$1000.1'
test2 = '$1.23'

re.findall(pattern, test1)
# Out:
# []

# %%
pattern = (\d{4}-\d-\d{4}-\d)
pattern2 = (\d{3}-\d{3}-\d{3}-\d)

pattern = (\d{4}-\d-\d{4}-\d)|(\d{3}-\d{3}-\d{3}-\d)
# Out:
#   File "C:\Users\singl\AppData\Local\Temp/ipykernel_50324/2497219532.py", line 1
#     pattern = (\d{4}-\d-\d{4}-\d)
#                                 ^
# SyntaxError: unexpected character after line continuation character

# %%
def l2_dist(a, b):
    
    result = ((a - b) * (a - b)).sum()
    result = result ** 0.5
    return result 

import numpy as np 

c = np.array([[1,2], [3,4]])
d = np.array([[3,4], [5,6]])

print(c)
print(c.T)

np.reshape(c, (4,1),2)
c
# Out:
# [[1 2]
#  [3 4]]
# [[1 3]
#  [2 4]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#
# TypeError: order must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50324/3207229772.py in <module>
#      13 print(c.T)
#      14
# ---> 15 np.reshape(c, (4,1),2)
#      16 c
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
# ...

# %%
a1 = np.random.rand(4)
a2 = np.random.rand(4, 1)
a3 = np.array([[1, 2, 3, 4]])
a4 = np.arange(1, 4, 1)
a5 = np.linspace(1 ,4, 4)
print (a1)
print (a2)
print(a3)
print(a4)
print(a5)
# Out:
# [0.37229203 0.48258802 0.94830555 0.63034548]
# [[0.16823401]
#  [0.47459043]
#  [0.61046591]
#  [0.59144142]]
# [[1 2 3 4]]
# [1 2 3]
# [1. 2. 3. 4.]

# %%
np.random
