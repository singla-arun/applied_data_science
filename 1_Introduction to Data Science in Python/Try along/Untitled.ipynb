# %%
import numpy as np
np.random.rand
# Out:
# <module 'numpy.random' from 'C:\\Users\\singl\\anaconda3\\lib\\site-packages\\numpy\\random\\__init__.py'>

# %%
a =np.random.rand(4,1)
a.shape
print(a)
# Out:
# [[0.85526235]
#  [0.5100646 ]
#  [0.64957275]
#  [0.28887455]]

# %%
a =np.random.rand(4)
print(a)
a.shape
# Out:
# [0.85520594 0.92988336 0.50130964 0.36964629]
# (4,)

# %%
a5 = np.linspace(1,4,4) 
print(a5)
# Out:
# [1. 2. 3. 4.]

# %%
a5.ndim
# Out:
# 1

# %%
import re

string = "https://google.com"
string2 = "http://www.baidu.com"
pattern =  "(?<=[https]:\/\/)([A-Za-z0-9.]*)"

re.findall(pattern, string2)
# Out:
# ['www.baidu.com']
