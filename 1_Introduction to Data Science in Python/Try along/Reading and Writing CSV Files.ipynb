# %%
    import csv

    #del list
 
    sports  =  list ( ('baseball', 'football', 'soccer', 'hockey', 'basketball') )
    print(sports)
# Out:
# ['baseball', 'football', 'soccer', 'hockey', 'basketball']

# %%
import csv

# %precision  2

with open(r'C:\Users\singl\Applied Data Science -University of Michigan\Files\home\jovyan\work\resources\course1\week-1\datasets\mpg.csv') as csvfile:
    mpg = list(csv.DictReader(csvfile))
        
mpg[:3]
# Out:
# [{'': '1',
#   'manufacturer': 'audi',
#   'model': 'a4',
#   'displ': '1.8',
#   'year': '1999',
#   'cyl': '4',
#   'trans': 'auto(l5)',
#   'drv': 'f',
#   'cty': '18',
#   'hwy': '29',
#   'fl': 'p',
#   'class': 'compact'},
#  {'': '2',
#   'manufacturer': 'audi',
#   'model': 'a4',
#   'displ': '1.8',
#   'year': '1999',
#   'cyl': '4',
#   'trans': 'manual(m5)',
#   'drv': 'f',
#   'cty': '21',
#   'hwy': '29',
#   'fl': 'p',
#   'class': 'compact'},
#  {'': '3',
#   'manufacturer': 'audi',
#   'model': 'a4',
#   'displ': '2',
#   'year': '2008',
#   'cyl': '4',
#   'trans': 'manual(m6)',
#   'drv': 'f',
#   'cty': '20',
#   'hwy': '31',
#   'fl': 'p',
#   'class': 'compact'}]

# %%
# Create a set which has unique cyclinder types in the list of cars
mpg_len = len (mpg)
mpg_len
mpg[0]
# Out:
# {'': '1',
#  'manufacturer': 'audi',
#  'model': 'a4',
#  'displ': '1.8',
#  'year': '1999',
#  'cyl': '4',
#  'trans': 'auto(l5)',
#  'drv': 'f',
#  'cty': '18',
#  'hwy': '29',
#  'fl': 'p',
#  'class': 'compact'}

# %%
list = []
print(type(list))

for x in range (mpg_len-1):
    mpg[x]['cyl']
    #print(mpg[x]['cyl'])
    list.append(mpg[x]['cyl']) 
    #print(list)

print(list)
cylinder_set = set(list)    
cylinder_set
# Out:
# <class 'list'>
# ...

# %%
AvgCtyMilesByCyliner = {}

for vehicle_type in cylinder_set: 
    print(vehicle_type)

print(x)

print(mpg[x]['cyl'] )
print(vehicle_type)

if mpg[x]['cyl'] == vehicle_type:
    print("True")
# Out:
# 6
# 4
# 5
# 8
# 232
# 6
# 8

# %%
AvgCtyMilesByCylinder ={}
for vehicle_type in cylinder_set: 
    print(vehicle_type)
    vehicle_type_miles =0 
    vehicle_type_count = 0 
    for x in range(mpg_len-1):
           if mpg[x]['cyl'] == vehicle_type:
                vehicle_type_miles =  vehicle_type_miles + int(mpg[x]['cty'])
                vehicle_type_count = vehicle_type_count +1 
    AvgCtyMilesByCylinder[vehicle_type] = vehicle_type_miles/ vehicle_type_count  

    print(AvgCtyMilesByCylinder)
# Out:
# 6
# {'6': 16.205128205128204}
# 4
# {'6': 16.205128205128204, '4': 21.012345679012345}
# 5
# {'6': 16.205128205128204, '4': 21.012345679012345, '5': 20.5}
# 8
# {'6': 16.205128205128204, '4': 21.012345679012345, '5': 20.5, '8': 12.571428571428571}

# %%
 dict(sorted(AvgCtyMilesByCylinder.items()))
# Out:
# {'4': 21.01, '5': 20.50, '6': 16.21, '8': 12.57}

# %%
import datetime as dt

# %%
dt.
# Out:
#   File "C:\Users\singl\AppData\Local\Temp/ipykernel_8308/345714265.py", line 1
#     dt.
#        ^
# SyntaxError: invalid syntax

# %%
dt
# Out:
# <module 'datetime' from 'C:\\Users\\singl\\anaconda3\\lib\\datetime.py'>

# %%
dt.
# Out:
#   File "C:\Users\singl\AppData\Local\Temp/ipykernel_8308/345714265.py", line 1
#     dt.
#        ^
# SyntaxError: invalid syntax
